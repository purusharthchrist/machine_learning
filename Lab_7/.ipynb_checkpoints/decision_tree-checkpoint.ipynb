# %% [markdown]
# # Lab 7
#
# Registration No.: 2348542
#
# Name: Purusharth Malik

# %% [markdown]
# ## Importing the libraries and Loading the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_palette('crest')

# %%
df = pd.read_csv('employee_data (1) 2.csv')
df.head()
# Out:
#    avg_monthly_hrs   department  filed_complaint  last_evaluation  n_projects  \
# 0              221  engineering              NaN         0.932868           4
# 1              232      support              NaN              NaN           3
# 2              184        sales              NaN         0.788830           3
# 3              206        sales              NaN         0.575688           4
# 4              249        sales              NaN         0.845217           3
#
#    recently_promoted  salary  satisfaction    status  tenure
# 0                NaN     low      0.829896      Left     5.0
# 1                NaN     low      0.834544  Employed     2.0
# 2                NaN  medium      0.834988  Employed     3.0
# 3                NaN     low      0.424764  Employed     2.0
# 4                NaN     low      0.779043  Employed     3.0

# %%
df.describe()
# Out:
#        avg_monthly_hrs  filed_complaint  last_evaluation    n_projects  \
# count     14249.000000           2058.0     12717.000000  14249.000000
# mean        199.795775              1.0         0.718477      3.773809
# std          50.998714              0.0         0.173062      1.253126
# min          49.000000              1.0         0.316175      1.000000
# 25%         155.000000              1.0         0.563866      3.000000
# 50%         199.000000              1.0         0.724939      4.000000
# 75%         245.000000              1.0         0.871358      5.000000
# max         310.000000              1.0         1.000000      7.000000
#
#        recently_promoted  satisfaction        tenure
# count              300.0  14068.000000  14068.000000
# mean                 1.0      0.621295      3.497228
# std                  0.0      0.250469      1.460917
# min                  1.0      0.040058      2.000000
# 25%                  1.0      0.450390      3.000000
# 50%                  1.0      0.652527      3.000000
# 75%                  1.0      0.824951      4.000000
# max                  1.0      1.000000     10.000000

# %%
df.shape
# Out:
# (14249, 10)

# %%
df.isna().sum()
# Out:
# avg_monthly_hrs          0
# department             709
# filed_complaint      12191
# last_evaluation       1532
# n_projects               0
# recently_promoted    13949
# salary                   0
# satisfaction           181
# status                   0
# tenure                 181
# dtype: int64

# %%
#replacing the null values with 0
df.fillna({'filed_complaint':0, 'recently_promoted':0}, inplace=True)
df.filed_complaint.unique(), df.recently_promoted.unique()
# Out:
# (array([0., 1.]), array([0., 1.]))

# %%
#we will remove the people who have not been evaluated from the dataset
df.dropna(subset=['last_evaluation', 'department'], inplace=True)

# %%
df.isna().sum()
# Out:
# avg_monthly_hrs      0
# department           0
# filed_complaint      0
# last_evaluation      0
# n_projects           0
# recently_promoted    0
# salary               0
# satisfaction         0
# status               0
# tenure               0
# dtype: int64

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Histogram

# %%
df_count = df.tenure.value_counts()
sns.barplot(x=df_count.index, y=df_count.values)
plt.title('Number of employees by tenure')
plt.show()

# %%
left = df[df.status=='Left']
left_count = left.tenure.value_counts()
sns.barplot(x=left_count.index, y=left_count.values)
plt.title('Number of employees (status=left) by tenure')
plt.show()

# %% [markdown]
# <b><u>Trend</u></b>
#
# Within the first 2 years, hardly anyone leaves the company. By the third year, employees start to figure out if this is working for them or not. After that, the longer an employee stays in the company, higher are their chances of staying with the company.

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(data=df, x='status', y='satisfaction')
plt.show()

# %% [markdown]
# Clearly, people who are still employed at the company have, on average, higher satisfaction level than the people who left.

# %% [markdown]
# ### Pie Chart

# %%
plt.pie(df.status.value_counts().values,
        labels=df.status.value_counts().index,
        explode=[0, 0.1],
        autopct='%0.01f%%'
        )
plt.title('Distribution of attrition')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
sns.set_palette('muted')
sns.scatterplot(data=df, 
                x='satisfaction', 
                y='last_evaluation',
                hue='status',
                alpha=0.5)
plt.legend(bbox_to_anchor=(1, 1.025))
plt.title('Satisfaction v/s Last Evaluation')
plt.show()

# %% [markdown]
# There are 3 major clusters of people who have left the company.
#
# 1. People who were evaluated long ago and are unsatisfied.
#
# 2. People who were recently evaluated and are unsatified.
#
# 3. People who were recently evaluated and are highly satisfied.
#
# Most of the people come under the first and second category. The reason behind the 3rd type of people leaving the company might be that they feel like they are now very comfortable in the company and would like to switch things up a little bit.

# %%
df[df.status=='Left'][['satisfaction', 'last_evaluation']].corr()
# Out:
#                  satisfaction  last_evaluation
# satisfaction         1.000000         0.177681
# last_evaluation      0.177681         1.000000

# %% [markdown]
# It was very evident from the scatter plot but here have quantified the fact that the two variables are not correlated with eachother for people who have left the company.

# %% [markdown]
# ## Decision Tree Modeling with Tree Pruning and Split Criteria

# %% [markdown]
# ### Build a decision tree

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
numeric = df[df.dtypes[df.dtypes!=object].index]

# %%
X, y = numeric.values, le.fit_transform(df['status'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                   test_size=0.2,
                                                   stratify=y,
                                                   random_state=42)

# %%
#decision tree with gini impurity
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, f1_score

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)

y_pred = dt.predict(X_test)

print(f'F1-score: {f1_score(y_test, y_pred)}')
confusion_matrix(y_test, y_pred)
# Out:
# F1-score: 0.9220338983050848
# array([[1779,   46],
#        [  46,  544]], dtype=int64)

# %%
#decision tree with entropy
dt = DecisionTreeClassifier(criterion='entropy')
dt.fit(X_train, y_train)

y_pred = dt.predict(X_test)

print(f'F1-score: {f1_score(y_test, y_pred)}')
confusion_matrix(y_test, y_pred)
# Out:
# F1-score: 0.9292412617220801
# array([[1787,   38],
#        [  45,  545]], dtype=int64)

# %% [markdown]
# In this particular case, entropy gives a relatively better model than gini impurity.

# %% [markdown]
# ### Visualizing the tree structure

# %%
from sklearn.tree import export_graphviz
from IPython.display import SVG
from graphviz import Source

graph = Source(export_graphviz(dt, out_file=None, feature_names=numeric.columns))
SVG(graph.pipe(format='svg'))

# %%
#depth of the tree
print(f'The depth of the tree is: {dt.get_depth()}')
# Out:
# The depth of the tree is: 22

# %%
#looking at feature importances
feature_imp = dict(zip(numeric.columns, dt.feature_importances_))
feature_imp
# Out:
# {'avg_monthly_hrs': 0.23337239179923977,
#  'filed_complaint': 0.0037372590870357603,
#  'last_evaluation': 0.13249996052543786,
#  'n_projects': 0.15033175418301142,
#  'recently_promoted': 0.0006071343028071477,
#  'satisfaction': 0.27355766930848613,
#  'tenure': 0.20589383079398196}

# %% [markdown]
# Thus the most important features(in order) are:
# ```
# 1. satisfaction
# 2. avg_monthly_hrs
# 3. tenure
# ```
#
# We can also see that in the tree, the first split happens on `satisfaction`.

# %%
dt.cost_complexity_pruning_path(X_train, y_train)
# Out:
# {'ccp_alphas': array([0.00000000e+00, 1.42592521e-04, 1.90123361e-04, 1.97651454e-04,
#         2.07039337e-04, 2.07039337e-04, 2.07039337e-04, 2.07039337e-04,
#         2.07039337e-04, 2.07039337e-04, 2.07039337e-04, 2.07039337e-04,
#         2.07039337e-04, 2.07039337e-04, 2.07039337e-04, 2.14374195e-04,
#         2.34437112e-04, 2.34437112e-04, 2.43117551e-04, 2.50231204e-04,
#         2.51281210e-04, 2.51281210e-04, 2.51489541e-04, 2.57029100e-04,
#         2.59826317e-04, 2.68746377e-04, 2.71592485e-04, 2.74347310e-04,
#         2.76052450e-04, 2.85185042e-04, 2.85185042e-04, 2.85185042e-04,
#         2.85185042e-04, 2.85185042e-04, 2.85185042e-04, 2.85185042e-04,
#         2.85185042e-04, 2.85185042e-04, 2.85185042e-04, 2.93423070e-04,
#         2.97244053e-04, 3.00297399e-04, 3.00722489e-04, 3.07018862e-04,
#         3.08135368e-04, 3.12724844e-04, 3.18969619e-04, 3.20871646e-04,
#         3.20890326e-04, 3.23592430e-04, 3.24819412e-04, 3.27394876e-04,
#         3.32463474e-04, 3.34627637e-04, 3.35932971e-04, 3.35932971e-04,
#         3.35932971e-04, 3.35932971e-04, 3.38785265e-04, 3.39248264e-04,
#         3.40264646e-04, 3.40264646e-04, 3.41655282e-04, 3.45455108e-04,
#         3.47910888e-04, 3.50577413e-04, 3.54661113e-04, 3.56966716e-04,
#         3.64354186e-04, 3.66365583e-04, 3.73668786e-04, 3.73668786e-04,
#         3.73668786e-04, 3.74675250e-04, 3.76499178e-04, 3.77342242e-04,
#         3.78000461e-04, 3.78000461e-04, 3.80718633e-04, 3.82256400e-04,
#         3.86514039e-04, 3.91388389e-04, 3.92860995e-04, 4.03740635e-04,
#         4.03740635e-04, 4.06444739e-04, 4.09747000e-04, 4.09747000e-04,
#         4.11167146e-04, 4.14078675e-04, 4.24811628e-04, 4.28748390e-04,
#         4.29084472e-04, 4.36231379e-04, 4.37571278e-04, 4.39836573e-04,
#         4.41783519e-04, 4.46046472e-04, 4.46880211e-04, 4.48326174e-04,
#         4.51930533e-04, 4.53421599e-04, 4.64294528e-04, 4.65962912e-04,
#         4.66682388e-04, 4.68182282e-04, 4.68857380e-04, 4.74736825e-04,
#         4.75195962e-04, 4.91796379e-04, 4.99302492e-04, 5.02562419e-04,
#         5.05236493e-04, 5.13546375e-04, 5.20655326e-04, 5.21229032e-04,
#         5.26518253e-04, 5.26518253e-04, 5.28180092e-04, 5.41893905e-04,
#         5.42830705e-04, 5.43857594e-04, 5.47653878e-04, 5.48694620e-04,
#         5.55172583e-04, 5.59882395e-04, 5.60101798e-04, 5.61758936e-04,
#         5.66922657e-04, 5.71136753e-04, 5.77825555e-04, 5.83787801e-04,
#         5.84934387e-04, 5.92207762e-04, 6.05810320e-04, 6.28449437e-04,
#         6.29931674e-04, 6.47850785e-04, 6.58442619e-04, 6.59231875e-04,
#         6.71865942e-04, 6.82330789e-04, 7.00781854e-04, 7.05985381e-04,
#         7.10050121e-04, 7.67114779e-04, 7.82154343e-04, 8.15339813e-04,
#         8.28157350e-04, 8.52136627e-04, 8.72975620e-04, 8.90009194e-04,
#         9.00671897e-04, 9.11710557e-04, 9.12087615e-04, 9.36272526e-04,
#         9.36420215e-04, 9.83412667e-04, 1.00439766e-03, 1.00461943e-03,
#         1.02258239e-03, 1.15283283e-03, 1.16584456e-03, 1.26684210e-03,
#         1.29576578e-03, 1.36877956e-03, 1.38006413e-03, 1.41681159e-03,
#         1.63828221e-03, 1.65633939e-03, 1.74096489e-03, 1.77387570e-03,
#         1.95981925e-03, 2.01673785e-03, 2.27660018e-03, 2.42074440e-03,
#         2.56244335e-03, 2.58773787e-03, 2.96849155e-03, 3.05956024e-03,
#         3.82867953e-03, 3.91362440e-03, 4.03381029e-03, 5.17427440e-03,
#         7.81347082e-03, 8.83801624e-03, 1.08376275e-02, 1.24277677e-02,
#         1.36523281e-02, 1.45644565e-02, 2.51383957e-02, 2.67400943e-02,
#         3.72116683e-02, 5.33387051e-02, 6.13912359e-02, 1.23944810e-01,
#         1.47227073e-01]),
#  'impurities': array([0.00000000e+00, 2.85185042e-04, 8.55555125e-04, 1.44850949e-03,
#         1.65554882e-03, 1.86258816e-03, 2.27666684e-03, 2.48370617e-03,
#         2.69074551e-03, 3.31186352e-03, 3.51890286e-03, 3.72594220e-03,
#         3.93298154e-03, 4.14002087e-03, 4.55409955e-03, 4.98284794e-03,
#         5.45172216e-03, 5.68615928e-03, 5.92927683e-03, 6.42973924e-03,
#         6.93230166e-03, 7.43486408e-03, 8.18933270e-03, 8.70339090e-03,
#         1.00025225e-02, 1.13462544e-02, 1.24326243e-02, 1.29813189e-02,
#         1.38094763e-02, 1.40946613e-02, 1.43798464e-02, 1.46650314e-02,
#         1.49502164e-02, 1.52354015e-02, 1.58057716e-02, 1.60909566e-02,
#         1.63761417e-02, 1.66613267e-02, 1.69465117e-02, 1.72399348e-02,
#         1.78344229e-02, 1.81347203e-02, 1.84354428e-02, 1.87424617e-02,
#         1.93587324e-02, 1.99841821e-02, 2.06221213e-02, 2.15847363e-02,
#         2.19056266e-02, 2.31999963e-02, 2.38496351e-02, 2.45044249e-02,
#         2.48368884e-02, 2.55061436e-02, 2.58420766e-02, 2.61780096e-02,
#         2.65139425e-02, 2.68498755e-02, 2.75274460e-02, 2.88844391e-02,
#         2.92247037e-02, 2.95649684e-02, 2.99066237e-02, 3.05975339e-02,
#         3.12933557e-02, 3.19945105e-02, 3.27038327e-02, 3.34177661e-02,
#         3.37821203e-02, 3.52475827e-02, 3.56212514e-02, 3.63685890e-02,
#         3.67422578e-02, 3.71169331e-02, 3.74934322e-02, 3.78707745e-02,
#         3.82487749e-02, 3.86267754e-02, 3.97689313e-02, 4.05334441e-02,
#         4.13064722e-02, 4.20892490e-02, 4.28749709e-02, 4.32787116e-02,
#         4.36824522e-02, 4.40888969e-02, 4.44986439e-02, 4.49083909e-02,
#         4.57307252e-02, 4.61448039e-02, 4.91184853e-02, 4.95472337e-02,
#         5.21217405e-02, 5.34304347e-02, 5.38680059e-02, 5.47476791e-02,
#         5.65148132e-02, 5.74069061e-02, 5.78537863e-02, 5.96470910e-02,
#         6.00990216e-02, 6.10058648e-02, 6.19344538e-02, 6.51961942e-02,
#         6.70629237e-02, 6.79992883e-02, 6.89370031e-02, 6.98864767e-02,
#         7.08368686e-02, 7.13286650e-02, 7.18279675e-02, 7.23305299e-02,
#         7.28357664e-02, 7.48899519e-02, 7.64519179e-02, 7.85368340e-02,
#         7.90633523e-02, 7.95898705e-02, 8.01180506e-02, 8.06599445e-02,
#         8.12027752e-02, 8.17466328e-02, 8.22942867e-02, 8.28429813e-02,
#         8.50636717e-02, 8.56235541e-02, 8.61836559e-02, 8.67454148e-02,
#         8.84461828e-02, 8.95884563e-02, 9.24775840e-02, 9.59803108e-02,
#         9.65652452e-02, 9.89340763e-02, 1.03780559e-01, 1.04409008e-01,
#         1.06298803e-01, 1.07594505e-01, 1.08252947e-01, 1.08912179e-01,
#         1.09584045e-01, 1.10948707e-01, 1.11649489e-01, 1.13061459e-01,
#         1.13771510e-01, 1.14538624e-01, 1.15320779e-01, 1.16136119e-01,
#         1.16964276e-01, 1.17816413e-01, 1.18689388e-01, 1.19579397e-01,
#         1.20480069e-01, 1.24126911e-01, 1.25951087e-01, 1.27823632e-01,
#         1.28760052e-01, 1.29743465e-01, 1.30747862e-01, 1.31752482e-01,
#         1.32775064e-01, 1.36233563e-01, 1.37399407e-01, 1.38666249e-01,
#         1.39962015e-01, 1.41330795e-01, 1.42710859e-01, 1.44127670e-01,
#         1.47404235e-01, 1.49060574e-01, 1.50801539e-01, 1.52575415e-01,
#         1.54535234e-01, 1.56551972e-01, 1.58828572e-01, 1.61249316e-01,
#         1.63811760e-01, 1.66399498e-01, 1.69367989e-01, 1.75487110e-01,
#         1.79315789e-01, 1.83229414e-01, 1.87263224e-01, 1.97611773e-01,
#         2.05425244e-01, 2.14263260e-01, 2.25100887e-01, 2.37528655e-01,
#         2.51180983e-01, 2.65745440e-01, 2.90883835e-01, 3.17623929e-01,
#         3.54835598e-01, 4.08174303e-01, 5.30956775e-01, 6.54901585e-01,
#         8.02128657e-01])}
